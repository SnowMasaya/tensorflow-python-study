# %% [markdown]
# # Tensorflow Python

# %% [markdown]
# Tensorflow Perceptron

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
# %matplotlib inline

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.examples.tutorials.mnist import input_data

import numpy as np
import tensorflow as tf
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %% [markdown]
# # MNIST_LOGISTIC

# %%
IMAGE_SIZE = 28 * 28
CATEGORY_NUM = 1
LEARNING_RATE = 0.1
TRAINING_LOOP = 20000
BATCH_SIZE = 100
SUMMARY_DIR = 'log_logistic'
SUMMARY_INTERVAL = 100

mnist = input_data.read_data_sets("data", one_hot=True)

def weight_variable(shape, name=None):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial, name=name)

def bias_variable(shape, name=""):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial, name=name)
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %%
with tf.Graph().as_default():
    with tf.name_scope("input"):
        y_ = tf.placeholder(tf.float32, [None, CATEGORY_NUM], name="labels")
        x = tf.placeholder(tf.float32, [None, IMAGE_SIZE], name="input_images")
    
    with tf.name_scope("readout"):
        W = weight_variable([IMAGE_SIZE, CATEGORY_NUM], name="weight")
        b = bias_variable([CATEGORY_NUM], name="bias")
        y = tf.nn.sigmoid(tf.matmul(x, W) + b)
        
    with tf.name_scope("optimize"):
        log_likelihood = tf.reduce_mean(tf.reduce_sum(y * tf.log(y) + tf.log(1 - y), reduction_indices=[1]))
        train_step = tf.train.GradientDescentOptimizer(LEARNING_RATE).minimize(-log_likelihood)
        log_likelihood_summary = tf.scalar_summary("log likelihood", log_likelihood)

    with tf.Session() as sess:
        train_writer = tf.train.SummaryWriter(SUMMARY_DIR + "/train", sess.graph)
        test_writer = tf.train.SummaryWriter(SUMMARY_DIR + "/test", sess.graph)
        
        correct_prediction = tf.equal(tf.sign(y - 0.5), tf.sign(y_ - 0.5))
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
        train_accuracy_summary = tf.scalar_summary("accuracy", accuracy)
        test_accuracy_summary = tf.scalar_summary("accuracy", accuracy)
        
        sess.run(tf.initialize_all_variables())
        for i in range(TRAINING_LOOP + 1):
            images, labels = mnist.train.next_batch(BATCH_SIZE)
            labels = [[1] if l[0] == 1 else [0] for l in labels]
            sess.run(train_step, {x: images, y_:labels})
            
            if i % SUMMARY_INTERVAL == 0:
                print("step %d" % i)
                summary = sess.run(tf.merge_summary([log_likelihood_summary, train_accuracy_summary]), {x: images, y_:labels})
                train_writer.add_summary(summary, i)
                summary = sess.run(tf.merge_summary([test_accuracy_summary]), {x: mnist.test.images, y_: [[1] if l[0] == 1 else [0] for l in mnist.test.labels]})
                test_writer.add_summary(summary, i)
# Out:
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:14 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:17 in <module>.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:18 in <module>.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:22 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:23 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:25 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# step 0
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 100
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 200
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 300
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 400
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 500
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 600
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 700
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 800
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 900
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 1000
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 1100
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 1200
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 1300
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 1400
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 1500
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 1600
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 1700
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 1800
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 1900
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 2000
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 2100
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 2200
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 2300
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 2400
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 2500
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 2600
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 2700
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 2800
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 2900
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 3000
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 3100
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 3200
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 3300
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 3400
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 3500
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 3600
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 3700
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 3800
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 3900
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 4000
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 4100
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 4200
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 4300
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 4400
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 4500
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 4600
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 4700
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 4800
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 4900
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 5000
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 5100
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 5200
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 5300
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 5400
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 5500
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 5600
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 5700
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 5800
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 5900
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 6000
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 6100
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 6200
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 6300
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 6400
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 6500
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 6600
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 6700
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 6800
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 6900
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 7000
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 7100
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 7200
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 7300
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 7400
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 7500
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 7600
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 7700
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 7800
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 7900
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 8000
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 8100
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 8200
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 8300
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 8400
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 8500
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 8600
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 8700
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 8800
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 8900
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 9000
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 9100
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 9200
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# ...
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 16900
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 17000
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 17100
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 17200
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 17300
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 17400
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 17500
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 17600
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 17700
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 17800
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 17900
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 18000
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 18100
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 18200
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 18300
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 18400
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 18500
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 18600
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 18700
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 18800
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 18900
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 19000
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 19100
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 19200
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 19300
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 19400
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 19500
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 19600
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 19700
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 19800
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 19900
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# step 20000
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:33 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From <ipython-input-7-af68db057652>:35 in <module>.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
